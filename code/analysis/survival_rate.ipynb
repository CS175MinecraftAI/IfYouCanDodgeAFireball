# %%
import numpy as np
import matplotlib.pyplot as plt
diag1 = np.genfromtxt("analytic-fireball.txt",delimiter=None) # load the text file
diag2 = np.genfromtxt("analytic-originalpos.txt",delimiter=None) # load the text file

plt.figure(figsize=(2^16,2^8))
plt.scatter(diag1[:,0],diag1[:,-1],s=5)
plt.show()

plt.figure(figsize=(2^16,2^8))
plt.scatter(diag2[:,0],diag2[:,-1],s=5)
plt.show()

# %%
fireball = [0.74468, 0.89583, 0.83582, 0.90698, 0.83333, 0.83051, 0.88525, 0.87179, 0.90000, 0.96296, 0.89216, 0.83951, 0.93605, 0.93782, 0.91837, 0.95135, 0.97129,0.93548,0.99450]
originalpos = [0.89005, 0.95131, 0.91915, 0.93023, 0.90083, 0.91515, 0.91837, 0.87805,0.97572]

fireball_death_time = [47,143,210,339,375,434,495,534,594,918,1020,1101,1273,1466,1613,1798,2216,2309,2491]
originalpos_death_time = [191,725,960,1132,1253,1418,1565,1688,2512]

cum_dodge_rate_fireball = []
cum_dodge_rate_originalpos = []
temp = 0

for i,k in enumerate(fireball):
        temp += k
        cum_dodge_rate_fireball.append(temp/(i+1))

temp = 0
for i,k in enumerate(originalpos):
        temp += k
        cum_dodge_rate_originalpos.append(temp/(i+1))
        
print "fireball approach dodge rate over life time: "
print cum_dodge_rate_fireball

print "original position approach dodge rate over life time: "
print cum_dodge_rate_originalpos

plt.figure(figsize=(2^12,2^4))
plt.plot(fireball_death_time,cum_dodge_rate_fireball)
plt.scatter(fireball_death_time,cum_dodge_rate_fireball)

#plt.figure(figsize=(2^10,2^4))
plt.plot(originalpos_death_time,cum_dodge_rate_originalpos)
plt.scatter(originalpos_death_time,cum_dodge_rate_originalpos)
plt.show()
# Out:
# fireball approach dodge rate over life time:
# [0.74468, 0.820255, 0.8254433333333333, 0.8458275, 0.843328, 0.8411916666666667, 0.8474857142857143, 0.85052375, 0.8560211111111111, 0.8667150000000001, 0.869028181818182, 0.8665683333333335, 0.8719130769230771, 0.8766207142857144, 0.8794040000000002, 0.8839006250000001, 0.8890411764705883, 0.8916211111111111, 0.8970357894736841]
# original position approach dodge rate over life time:
# [0.89005, 0.9206799999999999, 0.92017, 0.922685, 0.918314, 0.9177866666666666, 0.91787, 0.9128925, 0.9198733333333333]

# %%
import numpy as np
import matplotlib.pyplot as plt

diag5 = np.genfromtxt("final/log_file_4ghast-1500-output.txt",delimiter=None) # load the text file

Last_Dead_List = [5, 11, 15, 32, 49, 54, 62, 64, 73, 83, 112, 124, 139, 145, 163, 179, 190, 199, 205, 212, 223, 227, 235, 243, 263, 274, 286, 299, 310, 315, 324, 328, 347, 355, 368, 390, 397, 421, 433, 455, 472, 483, 485, 510, 514, 519, 529, 565, 579, 590, 628, 654, 661, 689, 694, 708, 714, 731, 742, 748, 759, 762, 766, 786, 814, 819, 827, 839, 841, 855, 868, 872, 880, 895, 904, 914, 920, 937, 946, 949, 955, 962, 972, 975, 981, 985, 988, 1000, 1010, 1023, 1039, 1047, 1050, 1055, 1081, 1087, 1099, 1107, 1125, 1146, 1152, 1166, 1191, 1194, 1197, 1203, 1209, 1222, 1233, 1243, 1262, 1269, 1273, 1282, 1296, 1302, 1313, 1325, 1345, 1370, 1384, 1396, 1405, 1422, 1427, 1436, 1447, 1458, 1476, 1482, 1487, 1491]

Survival_Rates =['0.80000', '0.33333', '0.50000', '0.58824', '0.64706', '0.40000', '0.62500', '0.50000', '0.88889', '0.50000', '0.51724', '0.66667', '0.40000', '0.16667', '0.55556', '0.68750', '0.81818', '0.66667', '0.50000', '0.14286', '0.36364', '0.75000', '0.50000', '0.50000', '0.60000', '0.27273', '0.50000', '0.38462', '0.54545', '1.00000', '0.66667', '0.75000', '0.47368', '0.37500', '0.23077', '0.59091', '0.71429', '0.58333', '0.50000', '0.63636', '0.47059', '0.45455', '1.00000', '0.60000', '0.50000', '0.80000', '0.40000', '0.50000', '0.85714', '0.72727', '0.71053', '0.69231', '0.57143', '0.64286', '0.60000', '0.64286', '0.66667', '0.70588', '0.72727', '0.50000', '0.63636', '0.66667', '0.50000', '0.60000', '0.57143', '0.20000', '0.12500', '0.66667', '0.00000', '0.64286', '0.30769', '0.75000', '0.25000', '0.46667', '0.77778', '0.50000', '0.50000', '0.35294', '0.44444', '0.66667', '0.66667', '0.57143', '0.70000', '0.66667', '0.33333', '0.25000', '0.66667', '0.25000', '0.10000', '0.53846', '0.81250', '0.62500', '0.33333', '0.40000', '0.50000', '0.50000', '0.75000', '0.37500', '0.50000', '0.61905', '0.83333', '0.42857', '0.44000', '0.33333', '0.00000', '0.50000', '0.66667', '0.61538', '0.45455', '0.70000', '0.68421', '0.71429', '0.50000', '0.44444', '0.57143', '0.83333', '0.54545', '0.66667', '0.60000', '0.64000', '0.85714', '0.58333', '0.44444', '0.70588', '0.80000', '0.66667', '0.72727', '0.36364', '0.66667', '0.66667', '1.00000', '0.50000']
new_list = [float(i) for i in Survival_Rates]
print sum([float(i) for i in Survival_Rates])/len(Last_Dead_List)

cum_dodge_rate = []
temp = 0

for i,k in enumerate(new_list):
        temp += k
        cum_dodge_rate.append(temp/(i+1))

plt.figure(figsize=(2^12,2^4))
plt.plot(Last_Dead_List,cum_dodge_rate)
plt.show()
# Out:
# 0.557176742424

# %%
import numpy as np
import matplotlib.pyplot as plt

diag5 = np.genfromtxt("final/log_file_4ghast-300episode-output.txt",delimiter=None) # load the text file

Last_Dead_List = [4, 21, 32, 40, 77, 85, 94, 104, 122, 132, 146, 169, 185, 202, 220, 238, 245, 263, 270, 302, 323, 337, 344, 361, 380, 391, 429, 444, 453, 460, 476, 484, 500, 512, 530, 540, 565, 584, 609, 631, 645, 650, 658, 669, 683, 699, 710, 714, 736, 748, 759, 769, 780, 812, 823, 829, 842, 857, 867, 882, 900, 923, 930, 941, 949, 968, 981, 991, 1007, 1027, 1035, 1052, 1072, 1078, 1093, 1104, 1119, 1132, 1162, 1174, 1189, 1202, 1217, 1229, 1237, 1252, 1276, 1290, 1329, 1336, 1353, 1365, 1377, 1407, 1427, 1440, 1460, 1485, 1497, 1506, 1536, 1550, 1567, 1586, 1593, 1605, 1630, 1640, 1647, 1673, 1689, 1706, 1717, 1724, 1737, 1759, 1790, 1796, 1807, 1815, 1822, 1847, 1861, 1868, 1885, 1897, 1908, 1924, 1938, 1957, 1965, 1989, 2007, 2020, 2049, 2060, 2086, 2101, 2107, 2112, 2124, 2143, 2174, 2182, 2201, 2204, 2213, 2237, 2272, 2295, 2319, 2338, 2373, 2401, 2412, 2442, 2450, 2460, 2476, 2490, 2497, 2513, 2519, 2530, 2560, 2573, 2583, 2606, 2633, 2648, 2663, 2679, 2699, 2713, 2725, 2734, 2757, 2766, 2780, 2797, 2816, 2826, 2842, 2852, 2865, 2888, 2892, 2910, 2916, 2927, 2951, 2976, 2990, 3032, 3054, 3073, 3083, 3097, 3127, 3134, 3167, 3180, 3190, 3203, 3214, 3223, 3241, 3254, 3284, 3297, 3309, 3322, 3353, 3380, 3388, 3412, 3446, 3467, 3482, 3511, 3537, 3555, 3589, 3611, 3624, 3636, 3650, 3658, 3677, 3707, 3716, 3730, 3738, 3755, 3767, 3796, 3845, 3853, 3894, 3909, 3941, 3955, 3989, 3995, 3999, 4008, 4029, 4044, 4051, 4076, 4090, 4114, 4137, 4157, 4170, 4177, 4194, 4218, 4238, 4257, 4274, 4302, 4319, 4334, 4363, 4376, 4389, 4395, 4400, 4429, 4442, 4460, 4483, 4495, 4510, 4521, 4533, 4542, 4553, 4584, 4608, 4614, 4627, 4647, 4665, 4671, 4688, 4714, 4753, 4756, 4773, 4786, 4797, 4811, 4839, 4866, 4873, 4888, 4921, 4935, 4943]
Survival_Rates = ['0.25000', '0.05882', '0.00000', '0.00000', '0.24324', '0.12500', '0.44444', '0.30000', '0.33333', '0.20000', '0.35714', '0.26087', '0.31250', '0.17647', '0.33333', '0.22222', '0.14286', '0.22222', '0.28571', '0.37500', '0.52381', '0.50000', '0.14286', '0.17647', '0.31579', '0.09091', '0.31579', '0.26667', '0.22222', '0.14286', '0.31250', '0.12500', '0.31250', '0.16667', '0.16667', '0.30000', '0.40000', '0.26316', '0.28000', '0.31818', '0.35714', '0.00000', '0.37500', '0.18182', '0.35714', '0.31250', '0.09091', '0.25000', '0.31818', '0.08333', '0.09091', '0.40000', '0.36364', '0.21875', '0.27273', '0.16667', '0.46154', '0.40000', '0.30000', '0.20000', '0.22222', '0.21739', '0.28571', '0.18182', '0.12500', '0.47368', '0.15385', '0.10000', '0.37500', '0.35000', '0.00000', '0.41176', '0.15000', '0.00000', '0.13333', '0.09091', '0.46667', '0.30769', '0.26667', '0.41667', '0.13333', '0.15385', '0.40000', '0.41667', '0.37500', '0.40000', '0.41667', '0.14286', '0.15385', '0.00000', '0.35294', '0.25000', '0.25000', '0.40000', '0.20000', '0.23077', '0.35000', '0.28000', '0.25000', '0.22222', '0.26667', '0.35714', '0.23529', '0.31579', '0.14286', '0.25000', '0.28000', '0.40000', '0.14286', '0.11538', '0.18750', '0.35294', '0.36364', '0.28571', '0.46154', '0.18182', '0.32258', '0.00000', '0.27273', '0.25000', '0.14286', '0.36000', '0.42857', '0.14286', '0.11765', '0.16667', '0.36364', '0.12500', '0.35714', '0.42105', '0.25000', '0.37500', '0.22222', '0.23077', '0.31034', '0.09091', '0.34615', '0.26667', '0.16667', '0.20000', '0.08333', '0.26316', '0.29032', '0.25000', '0.10526', '0.00000', '0.22222', '0.20833', '0.20000', '0.39130', '0.20833', '0.21053', '0.31429', '0.39286', '0.36364', '0.23333', '0.12500', '0.20000', '0.18750', '0.14286', '0.28571', '0.31250', '0.00000', '0.27273', '0.20000', '0.30769', '0.10000', '0.30435', '0.22222', '0.13333', '0.20000', '0.50000', '0.30000', '0.28571', '0.41667', '0.33333', '0.08696', '0.33333', '0.21429', '0.17647', '0.26316', '0.10000', '0.25000', '0.20000', '0.07692', '0.21739', '0.00000', '0.27778', '0.33333', '0.27273', '0.45833', '0.32000', '0.28571', '0.21429', '0.22727', '0.21053', '0.30000', '0.14286', '0.23333', '0.28571', '0.27273', '0.07692', '0.30000', '0.23077', '0.09091', '0.44444', '0.44444', '0.23077', '0.16667', '0.15385', '0.25000', '0.23077', '0.16129', '0.33333', '0.12500', '0.20833', '0.20588', '0.33333', '0.46667', '0.31034', '0.30769', '0.38889', '0.38235', '0.31818', '0.46154', '0.25000', '0.28571', '0.12500', '0.21053', '0.36667', '0.22222', '0.28571', '0.12500', '0.23529', '0.58333', '0.13793', '0.26531', '0.37500', '0.34146', '0.40000', '0.37500', '0.28571', '0.35294', '0.16667', '0.00000', '0.44444', '0.23810', '0.13333', '0.42857', '0.36000', '0.00000', '0.20833', '0.26087', '0.35000', '0.07692', '0.14286', '0.35294', '0.20833', '0.10000', '0.21053', '0.23529', '0.35714', '0.11765', '0.26667', '0.34483', '0.30769', '0.15385', '0.33333', '0.60000', '0.24138', '0.38462', '0.22222', '0.34783', '0.16667', '0.33333', '0.27273', '0.41667', '0.44444', '0.18182', '0.29032', '0.08333', '0.16667', '0.07692', '0.35000', '0.22222', '0.33333', '0.52941', '0.23077', '0.28205', '0.00000', '0.11765', '0.15385', '0.18182', '0.14286', '0.28571', '0.40741', '0.14286', '0.33333', '0.21212', '0.35714', '0.25000']

new_list = [float(i) for i in Survival_Rates]
print sum([float(i) for i in Survival_Rates])/len(Last_Dead_List)

cum_dodge_rate = []
temp = 0

for i,k in enumerate(new_list):
        temp += k
        cum_dodge_rate.append(temp/(i+1))

plt.figure(figsize=(2^12,2^4))
plt.plot(Last_Dead_List,cum_dodge_rate)
plt.show()
                 
plt.figure(figsize=(2^16,2^8))
plt.scatter(diag5[:,0],diag5[:,-1],s=5)
plt.show()
# Out:
# 0.253439302326

# %%
plt.figure(figsize=(2^16,2^4))
plt.plot(diag5[:,0],diag5[:,-1])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

diag6 = np.genfromtxt("final/log_file_4ghast-1500fb-output.txt",delimiter=None) # load the text file

plt.figure(figsize=(2^16,2^4))
plt.plot(diag6[:,0],diag6[:,-1])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

diag6 = np.genfromtxt("final/log_file_4ghast-0-01_eps-output.txt",delimiter=None) # load the text file

plt.figure(figsize=(2^16,2^4))
plt.plot(diag6[:,0],diag6[:,-1])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

diag6 = np.genfromtxt("final/log_file_4ghast-0-01_eps_06alpha-output.txt",delimiter=None) # load the text file

plt.figure(figsize=(2^16,2^4))
plt.plot(diag6[:,0],diag6[:,-1])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

diag6 = np.genfromtxt("final/log_file_4ghast-0-01_eps_09alpha-output.txt",delimiter=None) # load the text file

plt.figure(figsize=(2^16,2^4))
plt.plot(diag6[:,0],diag6[:,-1])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

diag6 = np.genfromtxt("final/log_file_4ghast-0-01_eps_09alpha_07gamma-output.txt",delimiter=None) # load the text file

plt.figure(figsize=(2^16,2^4))
plt.plot(diag6[:,0],diag6[:,-1])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

diag6 = np.genfromtxt("final/log_file_4ghast-0-01_eps_09alpha_04gamma-output.txt",delimiter=None) # load the text file

plt.figure(figsize=(2^16,2^4))
plt.plot(diag6[:,0],diag6[:,-1])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

run1life = {1: 56.46499991416931, 2: 71.3659999370575, 3: 2.6459999084472656, 4: 38.03999996185303, 5: 80.35199999809265, 6: 152.24399995803833, 7: 38.325000047683716, 8: 19.87600016593933, 9: 89.07400012016296, 10: 128.50100016593933, 11: 89.59100008010864, 12: 74.06399989128113, 13: 74.25300002098083, 14: 86.47300004959106, 15: 95.22199988365173, 16: 41.30399990081787, 17: 23.45300006866455, 18: 47.43400001525879, 19: 62.20799994468689, 20: 14.349000215530396, 21: 40.960999965667725, 22: 112.99799990653992, 23: 40.4300000667572, 24: 22.847000122070312, 25: 61.95199990272522, 26: 38.16499996185303, 27: 32.22699999809265, 28: 98.40199995040894, 29: 152.26399993896484, 30: 181.0789999961853, 31: 167.2829999923706, 32: 8.33899998664856, 33: 50.30499982833862, 34: 77.11299991607666, 35: 284.5510001182556, 36: 26.48800015449524, 37: 64.8730001449585, 38: 41.50699996948242, 39: 71.33899998664856, 40: 80.20199990272522}
run2life = {1: 58.97200012207031, 2: 62.24000000953674, 3: 11.378000020980835, 4: 20.4689998626709, 5: 23.444000005722046, 6: 35.29200005531311, 7: 71.01199984550476, 8: 65.04800009727478, 9: 8.121000051498413, 10: 8.220999956130981, 11: 71.01399993896484, 12: 212.05599999427795, 13: 59.04100012779236, 14: 128.00400018692017, 15: 161.37199997901917, 16: 92.15199995040894, 17: 25.94099998474121, 18: 203.0279998779297, 19: 203.16100001335144, 20: 116.11199998855591, 21: 23.348999977111816, 22: 130.95300006866455, 23: 245.2649998664856, 24: 80.08899998664856, 25: 193.92900013923645, 26: 23.40400004386902, 27: 62.03099989891052, 28: 17.164000034332275, 29: 55.437999963760376, 30: 101.31100010871887, 31: 55.924999952316284, 32: 155.10800004005432, 33: 4.91700005531311, 34: 172.84799981117249, 35: 80.26900005340576, 36: 9.255000114440918, 37: 253.81700015068054, 38: 58.9539999961853, 39: 152.00400018692017, 40: 82.93400001525879}
run3life = {1: 20.118000030517578, 2: 31.794000148773193, 3: 116.40300011634827, 4: 92.0699999332428, 5: 41.40700006484985, 6: 95.19400000572205, 7: 53.49799990653992, 8: 32.22000002861023, 9: 185.02100014686584, 10: 251.19999980926514, 11: 101.16800022125244, 12: 95.49500012397766, 13: 62.39100003242493, 14: 89.45300006866455, 15: 59.29299998283386, 16: 65.43799996376038, 17: 68.42199993133545, 18: 17.403000116348267, 19: 47.20799994468689, 20: 44.34700012207031, 21: 182.106999874115, 22: 26.265000104904175, 23: 218.32800006866455, 24: 47.24499988555908, 25: 41.25999999046326, 26: 5.07099986076355, 27: 148.93799996376038, 28: 245.0110001564026, 29: 151.53799986839294, 30: 287.05399990081787, 31: 203.14800000190735, 32: 206.18300008773804, 33: 299.143000125885, 34: 38.0, 35: 17.111000061035156, 36: 116.32799983024597, 37: 26.259000062942505, 38: 299.460000038147, 39: 346.43300008773804, 40: 266.00100016593933}
run4life = {1: 128.11299991607666, 2: 23.170000076293945, 3: 68.21500015258789, 4: 35.06400012969971, 5: 113.29999995231628, 6: 53.414000034332275, 7: 47.10899996757507, 8: 194.12900018692017, 9: 59.21000003814697, 10: 113.01600003242493, 11: 50.43499994277954, 12: 35.06700015068054, 13: 32.442999839782715, 14: 32.13499999046326, 15: 26.447999954223633, 16: 95.74300003051758, 17: 65.83799982070923, 18: 14.139000177383423, 19: 59.36099982261658, 20: 88.43899989128113, 21: 241.90499997138977, 22: 29.02300000190735, 23: 251.0090000629425, 24: 221.36800003051758, 25: 224.2590000629425, 26: 203.19700002670288, 27: 104.375, 28: 20.29100012779236, 29: 53.125, 30: 74.32399988174438, 31: 65.29299998283386, 32: 62.444000005722046, 33: 59.13599991798401, 34: 64.86399984359741, 35: 11.027999877929688, 36: 110.18300008773804, 37: 119.17499995231628, 38: 182.12599992752075, 39: 140.0310001373291, 40: 194.382000207901}
run5life = {1: 8.004999876022339, 2: 119.18799996376038, 3: 2.820000171661377, 4: 5.001000165939331, 5: 23.210000038146973, 6: 104.14300012588501, 7: 8.316999912261963, 8: 16.868000030517578, 9: 23.308000087738037, 10: 23.164999961853027, 11: 80.37099981307983, 12: 88.22299981117249, 13: 38.414000034332275, 14: 113.35600018501282, 15: 38.43900012969971, 16: 29.348000049591064, 17: 47.319000005722046, 18: 47.388999938964844, 19: 38.03099989891052, 20: 221.1949999332428, 21: 62.062999963760376, 22: 44.00599980354309, 23: 163.9539999961853, 24: 135.52900004386902, 25: 65.22099995613098, 26: 167.4869999885559, 27: 53.17700004577637, 28: 110.15499997138977, 29: 14.305000066757202, 30: 149.22399997711182, 31: 59.03500008583069, 32: 65.16100001335144, 33: 95.06399989128113, 34: 23.11300015449524, 35: 35.29199981689453, 36: 29.147000074386597, 37: 38.420000076293945, 38: 122.375, 39: 56.228999853134155, 40: 98.08299994468689}

run1armor = {1: 188.24000000953674, 2: 236.10899996757507, 3: 146.1619999408722, 4: 305.9469997882843, 5: 389.0629999637604, 6: 241.99300003051758, 7: 458.0979998111725, 8: 284.29499983787537, 9: 191.36800003051758, 10: 320.3180000782013, 11: 282.2330000400543, 12: 248.30499982833862, 13: 278.3269999027252, 14: 440.3660001754761, 15: 206.18700003623962}
run2armor = {1: 205.46199989318848, 2: 284.11100006103516, 3: 275.19000005722046, 4: 445.9940001964569, 5: 227.17199993133545, 6: 382.94600009918213, 7: 188.2590000629425, 8: 181.06900000572205, 9: 581.2139999866486, 10: 287.38899993896484, 11: 253.97099995613098, 12: 308.27999997138977, 13: 205.6340000629425, 14: 377.3010001182556, 15: 302.0720000267029}
run3armor = {1: 151.55999994277954, 2: 194.1210000514984, 3: 308.92899990081787, 4: 203.07200002670288, 5: 335.0329999923706, 6: 275.33200001716614, 7: 251.04699993133545, 8: 391.93499994277954, 9: 332.27500009536743, 10: 566.1959998607635, 11: 344.1529998779297, 12: 620.2430000305176, 13: 301.978000164032, 14: 146.3420000076294, 15: 285.0659999847412}
run4armor = {1: 233.25500011444092, 2: 71.36700010299683, 3: 326.4170000553131, 4: 374.19900012016296, 5: 206.1470000743866, 6: 206.33200001716614, 7: 235.9689998626709, 8: 151.5519998073578, 9: 219.76500010490417, 10: 269.12999987602234, 11: 584.0099999904633, 12: 584.1389999389648, 13: 395.2079999446869, 14: 304.00999999046326, 15: 397.0499999523163}
run5armor = {1: 154.36100006103516, 2: 210.68700003623962, 3: 269.260999917984, 4: 251.00800013542175, 5: 179.02099990844727, 6: 140.5, 7: 173.73599982261658, 8: 153.8050000667572, 9: 191.53900003433228, 10: 194.5899999141693, 11: 377.22699999809265, 12: 475.43499994277954, 13: 428.1159999370575, 14: 341.1119999885559, 15: 332.1949999332428}

run1life = run1life.values()
run2life = run2life.values()
run3life = run3life.values()
run4life = run4life.values()
run5life = run5life.values()

print "total run 1 : ", sum(run1life)
print "total run 2 : ", sum(run2life)
print "total run 3 : ", sum(run3life)
print "total run 4 : ", sum(run4life)
print "total run 5 : ", sum(run5life)

sumrunlife = [0 for x in range(40)]
sumrunindex = list(range(0,40))

for x in range(0, 40):
    sumrunlife[x] = run1life[x] + run2life[x] + run3life[x] + run4life[x] + run5life[x] 
    
sumrunlife = np.array(sumrunlife)

diag7 = sumrunlife/5
print "total run avg : ",sum(diag7)

plt.figure(figsize=(2^16,2^4))
plt.plot(sumrunindex,run1life)
plt.plot(sumrunindex,run2life)
plt.plot(sumrunindex,run3life)
plt.plot(sumrunindex,run4life)
plt.plot(sumrunindex,run5life)
plt.plot(sumrunindex,diag7, linewidth=5)
plt.show()
# Out:
# total run 1 :  2938.56500006
# total run 2 :  3595.04200053
# total run 3 :  4740.42600083
# total run 4 :  3766.32600021
# total run 5 :  2663.14999986
# total run avg :  3540.7018003

# %%
run1armor = run1armor.values()
run2armor = run2armor.values()
run3armor = run3armor.values()
run4armor = run4armor.values()
run5armor = run5armor.values()

print "total run 1 : ", sum(run1armor)
print "total run 2 : ", sum(run2armor)
print "total run 3 : ", sum(run3armor)
print "total run 4 : ", sum(run4armor)
print "total run 5 : ", sum(run5armor)

sumrunarmor = [0 for x in range(15)]
sumrunindexarmor = list(range(0,15))

for x in range(0, 15):
    sumrunarmor[x] = run1armor[x] + run2armor[x] + run3armor[x] + run4armor[x] + run5armor[x] 
    
sumrunarmor = np.array(sumrunarmor)

diag8 = sumrunarmor/5
print "total run avg : ",sum(diag8)

plt.figure(figsize=(2^16,2^4))
plt.plot(sumrunindexarmor,run1armor)
plt.plot(sumrunindexarmor,run2armor)
plt.plot(sumrunindexarmor,run3armor)
plt.plot(sumrunindexarmor,run4armor)
plt.plot(sumrunindexarmor,run5armor)
plt.plot(sumrunindexarmor,diag8, linewidth=5)
plt.show()
# Out:
# total run 1 :  4217.01099944
# total run 2 :  4506.06400037
# total run 3 :  4707.28199983
# total run 4 :  4558.54999995
# total run 5 :  3872.5929997
# total run avg :  4372.29999986

# %%
plt.figure(figsize=(2^8,2^4))

sumrunindexarmor =  list(range(0,15))
sumrunindexarmor2 = list(range(0,150))

fit = np.polyfit(sumrunindex, diag7, deg=1)
plt.plot(sumrunindex, fit[0] * sumrunindex + fit[1], color="blue")

# calculate polynomial
z = np.polyfit(sumrunindexarmor, diag8, 3)
f = np.poly1d(z)
print f

# calculate new x's and y's
x_new = np.linspace(x[0], x[-1], 50)
y_new = f(x_new)

fit = np.polyfit(x_new, y_new, deg=1)
#plt.plot(x_new,y_new)
plt.plot(x_new, fit[0] * x_new + fit[1], color="blue")
#plt.plot(sumrunindexarmor,diag7[:15])
plt.plot(sumrunindex,diag7,c="green")
plt.plot(sumrunindexarmor,diag8,c="crimson")
plt.show()
# Out:
#          3         2
# -0.1757 x + 2.888 x + 1.525 x + 214.6
# C:\Users\Kyaa\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future

# %%
# MatPlotlib
import matplotlib.pyplot as plt
from matplotlib import pylab

# Scientific libraries
import numpy as np

sumrunindexarmor =  list(range(0,15))

# get x and y vectors
x = sumrunindexarmor
y = diag8

# calculate polynomial
z = np.polyfit(x, y, 3)
f = np.poly1d(z)
print f

# calculate new x's and y's
x_new = np.linspace(x[0], x[-1], 50)
y_new = f(x_new)


plt.plot(x,y,'o', x_new, y_new)
pylab.title('Polynomial Fit with Matplotlib')
ax = plt.gca()
ax.set_axis_bgcolor((0.898, 0.898, 0.898))
fig = plt.gcf()
# py.plot_mpl(fig, filename='polynomial-Fit-with-matplotlib')
plt.show()
# Out:
#          3         2
# -0.1757 x + 2.888 x + 1.525 x + 214.6

# %%
plt.figure(figsize=(2^12,2^4))

sumrunindexarmor =  list(range(0,15))
sumrunindexarmor2 = list(range(0,150))

fit = np.polyfit(sumrunindex, diag7, deg=1)
plt.plot(sumrunindex, fit[0] * sumrunindex + fit[1], color="blue")
plt.plot(sumrunindex,diag7,c="green",linewidth=5)
plt.show()

plt.figure(figsize=(2^12,2^4))
plt.plot(sumrunindexarmor,diag8,c="crimson",linewidth=5)
# calculate polynomial
z = np.polyfit(sumrunindexarmor, diag8, 3)
f = np.poly1d(z)
print f

# calculate new x's and y's
x_new = np.linspace(x[0], x[-1], 50)
y_new = f(x_new)

fit = np.polyfit(x_new, y_new, deg=1)
#plt.plot(x_new,y_new)
plt.plot(x_new, fit[0] * x_new + fit[1], color="blue")
#plt.plot(sumrunindexarmor,diag7[:15])

plt.show()
# Out:
# C:\Users\Kyaa\Anaconda2\lib\site-packages\ipykernel\__main__.py:7: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#          3         2
# -0.1757 x + 2.888 x + 1.525 x + 214.6
